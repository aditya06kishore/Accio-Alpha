# %% [markdown]
# # 1D Kalman Filter
#
# ## Problem Setup
# - True object moves in **1D**
# - We receive **noisy position measurements**
# - Goal: **estimate the true position over time** using a Kalman Filter
#
#
#
# ## Imports
# We use:
# - **NumPy** for numerical and matrix operations
# - **Matplotlib** for visualization

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Simulation Parameters
# We simulate an object moving with **constant velocity** in 1D.

# %%
np.random.seed(42)  # for reproducibility
n_steps = 50        # number of time steps
true_velocity = 1  # constant velocity
dt = 1.0           # time step

# %% [markdown]
# ## Generate True State and Noisy Measurements
# - `true_positions` → ground truth (unknown in real life)
# - `measurements` → noisy sensor readings

# %%
true_positions = []
measurements = []
position = 0.0
measurement_noise_std = 2.0  # sensor noise (R)
for _ in range(n_steps):
    position += true_velocity * dt
    true_positions.append(position)
    noisy_measurement = position + np.random.normal(0, measurement_noise_std)
    measurements.append(noisy_measurement)

# %% [markdown]
# ## Kalman Filter Initialization
# We initialize:
# - State estimate
# - Uncertainty
# - Model matrices
# - Noise values

# %%
# Initial state estimate (position only)
x_est = np.array([[0.0]])  # initial guess

# Initial uncertainty
P = np.array([[10.0]])     # large value = low confidence

# State transition matrix
F = np.array([[1.0]])

# Measurement matrix
H = np.array([[1.0]])

# Process noise (model uncertainty)
Q = np.array([[0.1]])

# Measurement noise (sensor uncertainty)
R = np.array([[measurement_noise_std ** 2]])

# %% [markdown]
# ## Kalman Filter Loop
# Each iteration performs:
# 1. Prediction
# 2. Update

# %%
estimates = []
for z in measurements:
    # ------------------
    # PREDICTION STEP
    # ------------------
    x_pred = F @ x_est
    P_pred = F @ P @ F.T + Q

    # ------------------
    # UPDATE STEP
    # ------------------
    S = H @ P_pred @ H.T + R
    K = P_pred @ H.T @ np.linalg.inv(S)

    y = np.array([[z]]) - H @ x_pred   # innovation
    x_est = x_pred + K @ y

    P = (np.eye(1) - K @ H) @ P_pred

    estimates.append(x_est.item())

# %% [markdown]
# ## Visualization
# You should observe:
# - Noisy measurements
# - Smooth Kalman estimate
# - Estimate closely following true position

# %%
plt.figure(figsize=(10, 5))
plt.plot(true_positions, label="True Position", linewidth=2)
plt.scatter(range(n_steps), measurements, label="Noisy Measurements", color="red", alpha=0.6)
plt.plot(estimates, label="Kalman Filter Estimate", linewidth=2)
plt.xlabel("Time Step")
plt.ylabel("Position")
plt.title("1D Kalman Filter: Position Estimation")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Code Extension

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
n_steps = 60
dt = 1.0
process_accel_std = 0.5      # random acceleration in true system
measurement_noise_std = 2.0  # sensor noise

true_positions = []
true_velocities = []
measurements = []
pos = 0.0
vel = 1.0

for _ in range(n_steps):
    accel = np.random.normal(0, process_accel_std)
    vel += accel * dt
    pos += vel * dt
    true_velocities.append(vel)
    true_positions.append(pos)
    z = pos + np.random.normal(0, measurement_noise_std)
    measurements.append(z)


x = np.array([[0.0],[0.0]])
P = np.eye(2) * 100.0
F = np.array([[1, dt],[0, 1]])
H = np.array([[1, 0]])
q = 0.5
Q = np.array([[0.25*dt**4, 0.5*dt**3],[0.5*dt**3, dt**2]]) * q
R = np.array([[measurement_noise_std**2]])
kf_estimates = []
prediction_only_estimates = []
x_pred_only = x.copy()
P_pred_only = P.copy()

for z in measurements:
    x = F @ x
    P = F @ P @ F.T + Q
    x_pred_only = F @ x_pred_only
    P_pred_only = F @ P_pred_only @ F.T + Q
    prediction_only_estimates.append(x_pred_only[0, 0])
    y = np.array([[z]]) - H @ x
    S = H @ P @ H.T + R
    K = P @ H.T @ np.linalg.inv(S)
    x = x + K @ y
    P = (np.eye(2) - K @ H) @ P
    kf_estimates.append(x[0, 0])

plt.figure(figsize=(10, 5))
plt.plot(true_positions, label="True Position", linewidth=2)
plt.scatter(range(n_steps), measurements, alpha=0.5, label="Measurements")
plt.plot(prediction_only_estimates, '--', label="Prediction Only - no updates")
plt.plot(kf_estimates, label="Kalman Filter Estimate", linewidth=2)
plt.xlabel("Time Step")
plt.ylabel("Position")
plt.title("Kalman filter with position and velocity state and random acceleration")
plt.grid(True)
plt.legend()
plt.show()
